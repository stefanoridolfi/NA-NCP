# %% [markdown]
# <a href="https://colab.research.google.com/github/stefanoridolfi/NA-NCP/blob/main/git_ncclint_csr_colab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install ncclient
#! pip install xmltodict
import os
import re
import json
from ncclient import manager
from  lxml import etree
import  xml.etree.ElementTree as ET
import xml.dom.minidom

import xmltodict
host='87.3.225.196'
#filter = "native/hostname"
#filter = "native/counters"
filter = "interfaces/interface"
#filter = "interfaces/interface[name='GigabitEthernet2.2']"
#filter = "interfaces/interface[name='GigabitEthernet2']/description"
#filter="routing"
print("get_config di:"+host)

with manager.connect(host=host, port=830, username='cisco', password='cisco',hostkey_verify=False,device_params={'name':'csr'}) as m:
    c2=m.get_config(source='running', filter=('xpath', filter))
#with manager.connect(host=host, port=830, username='cisco', password='cisco',hostkey_verify=False,device_params={'name':'csr'}) as m:
    #c2=m.get_config(source='running')
c2_data=c2.data_xml
#c2_dict=xmltodict.parse(c2_data)
#c2_json=json.dumps(c2_dict, sort_keys=True, indent=4)
#print("c2_json\n",c2_json)
c2_data=str(c2.data_xml)
xml = xml.dom.minidom.parseString(c2_data)
xml_pretty_str = xml.toprettyxml()
print (xml_pretty_str)
# Out:
# get_config di:87.3.225.196
# <?xml version="1.0" ?>
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
# 	<interfaces xmlns="http://openconfig.net/yang/interfaces">
# 		<interface>
# 			<name>GigabitEthernet1</name>
# 			<config>
# 				<name>GigabitEthernet1</name>
# 				<type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
# 				<enabled>true</enabled>
# 			</config>
# 			<subinterfaces>
# 				<subinterface>
# 					<index>0</index>
# 					<config>
# 						<index>0</index>
# 						<enabled>true</enabled>
# 					</config>
# 					<ipv4 xmlns="http://openconfig.net/yang/interfaces/ip">
# 						<addresses>
# 							<address>
# 								<ip>192.168.1.100</ip>
# 								<config>
# 									<ip>192.168.1.100</ip>
# 									<prefix-length>24</prefix-length>
# 								</config>
# 							</address>
# 						</addresses>
# 					</ipv4>
# 					<ipv6 xmlns="http://openconfig.net/yang/interfaces/ip">
# ...
